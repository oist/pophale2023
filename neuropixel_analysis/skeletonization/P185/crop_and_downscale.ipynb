# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage as ndi
import subprocess
from nomap.image_io import load_tiff_sequence, save_nifti

# %%
rootdir = "/bucket/ReiterU/DBS/data/20220517_P185_laqueus_DiI_L-M27/"
resultdir = os.path.join(rootdir, "analysis")
if not os.path.exists(resultdir):
    subprocess.run(["ssh", "deigo", "mkdir", resultdir])

# %%
cwd = os.path.basename(os.getcwd())
tmpdir = os.path.join("/flash/ReiterU/tmp/", cwd, "cropped")
if not os.path.exists(tmpdir):
    os.makedirs(tmpdir)

# %%
def main(imgpath, outpath, resize_factor, voxel_size):
    v = load_tiff_sequence(imgpath)
    v = v[420:2297, 75:1750, 585:2050] # Crop
    # v = np.swapaxes(v, 0, 1) # change XYZ order
    # v = v[::-1,::-1,:] # Flip
    
    # Show images
    for i in range(0, v.shape[0], 200):
        plt.imshow(v[i,:,:], cmap="gray")
        plt.show()
    
    v = ndi.zoom(v, zoom=resize_factor, order=2) # resize
    
    save_nifti(v, outpath, voxel_size, voxel_size, voxel_size)

# %%
main(os.path.join(rootdir, "stitched_536BP_25um/"),
     os.path.join(tmpdir, "536BP_10um.nii"), 0.25, 10)

# %%
main(os.path.join(rootdir, "stitched_593BP_25um/"),
     os.path.join(tmpdir, "593BP_5um.nii"), 0.5, 5)

# %%
subprocess.run(["scp", os.path.join(tmpdir, "536BP_10um.nii"),
                f"deigo:{resultdir}"])
# Out:
# CompletedProcess(args=['scp', '/flash/ReiterU/tmp/P185/cropped/536BP_10um.nii', 'deigo:/bucket/ReiterU/DBS/data/20220517_P185_laqueus_DiI_L-M27/analysis'], returncode=0)

# %%
subprocess.run(["scp", os.path.join(tmpdir, "593BP_5um.nii"),
                f"deigo:{resultdir}"])
# Out:
# CompletedProcess(args=['scp', '/flash/ReiterU/tmp/P185/cropped/593BP_5um.nii', 'deigo:/bucket/ReiterU/DBS/data/20220517_P185_laqueus_DiI_L-M27/analysis'], returncode=0)
